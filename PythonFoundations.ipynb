# %%
print("ADvance Python")
# Out:
# ADvance Python

# %%
print("My Name is Ahmad. \n I am a student of Advance Python Class")
# Out:
# My Name is Ahmad.
#  I am a student of Advance Python Class

# %%
#string
"ABC 123 !@#"
#Integer
12345
#Float
1.2
# Bool
# True False
# Out:
# 1.2

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
name = ""
numbers = 123
fl = 1.1
co = True

# %%
print(name)
print(numbers)
print(fl)
print(co)
# Out:
# 123
# 1.1
# True
